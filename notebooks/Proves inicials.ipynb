# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20, 15)

# %%
cryptocurrency='../data/raw/cryptocurrency/'
iris='../data/raw/iris/'
measures='../data/raw/measures/'

# %%
df = pd.read_csv(cryptocurrency+'bitcoin_price.csv', index_col='Date')

# %%
df.head()
# Out:
#                  Open     High      Low    Close      Volume   Market Cap
# Date
# Sep 05, 2017  4228.29  4427.84  3998.11  4376.53  2697970000  69954400000
# Sep 04, 2017  4591.63  4591.63  4108.40  4236.31  2987330000  75955500000
# Sep 03, 2017  4585.27  4714.08  4417.59  4582.96  1933190000  75841700000
# Sep 02, 2017  4901.42  4975.04  4469.24  4578.77  2722140000  81060600000
# Sep 01, 2017  4701.76  4892.01  4678.53  4892.01  2599080000  77748400000

# %%
pd.to_datetime(df.index)
# Out:
# DatetimeIndex(['2017-09-05', '2017-09-04', '2017-09-03', '2017-09-02',
#                '2017-09-01', '2017-08-31', '2017-08-30', '2017-08-29',
#                '2017-08-28', '2017-08-27',
#                ...
#                '2013-05-07', '2013-05-06', '2013-05-05', '2013-05-04',
#                '2013-05-03', '2013-05-02', '2013-05-01', '2013-04-30',
#                '2013-04-29', '2013-04-28'],
#               dtype='datetime64[ns]', name='Date', length=1592, freq=None)

# %%
f, axes = plt.subplots(3, 2)
sns.lineplot(x=df.index.values, y=df.Open.values)
